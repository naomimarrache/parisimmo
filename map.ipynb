# %%
import folium
paris = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)

# %%
#paris

# %%
#folium.Marker([48.856578, 2.351828], popup = "PARIS").add_to(paris)
#paris

# %%
#folium.CircleMarker([48.856578, 2.351828], popup = "PARIS", radius = 10).add_to(paris)
#paris

# %%
import json
geo = json.load(open("arrondissements.geojson"))

# %%
geo.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo["features"][0]['properties']
# Out:
# {'n_sq_co': 750001537,
#  'perimetre': 6483.68678565,
#  'l_ar': '6ème Ardt',
#  'surface': 2153095.58639283,
#  'geom_x_y': [48.8491303586, 2.33289799905],
#  'n_sq_ar': 750000006,
#  'l_aroff': 'Luxembourg',
#  'c_arinsee': 75106,
#  'c_ar': 6}

# %%
paris_arr_marker = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
for arr in geo["features"]:
    prop = arr["properties"]
    folium.Marker(prop["geom_x_y"], popup = prop["l_ar"]).add_to(paris_arr_marker)
paris_arr_marker
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
paris_arr_circle = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
for arr in geo["features"]:
    prop = arr["properties"]
    folium.CircleMarker(prop["geom_x_y"], 
                        popup = prop["l_ar"],
                        radius = prop["surface"] / 1000000).add_to(paris_arr_circle)
paris_arr_circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
paris = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
paris.choropleth( geo)
paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#       Unnamed: 0  arrondissement  nb_pieces  nb_chambres  surface    prix  \
# 0              0              17          1          NaN        7   84000
# 1              1              20          2          NaN       44   87250
# 2              2              17          1          NaN       12   97000
# 3              3              17          1          NaN        7   99000
# 4              4              11          1          NaN        7  105000
# ...          ...             ...        ...          ...      ...     ...
# 1310         533              18          1          0.0       28  268000
# 1311         534              18          2          1.0       27  265000
# 1312         535              18          2          1.0       44  455000
# 1313         536              18          3          2.0       65  409000
# 1314         537              18          2          1.0       45  430000
#
#                                                    lien       prix_mc
# 0     https://www.century21.fr/trouver_logement/deta...  12000.000000
# 1     https://www.century21.fr/trouver_logement/deta...   1982.954545
# 2     https://www.century21.fr/trouver_logement/deta...   8083.333333
# 3     https://www.century21.fr/trouver_logement/deta...  14142.857143
# 4     https://www.century21.fr/trouver_logement/deta...  15000.000000
# ...                                                 ...           ...
# 1310  https://www.pap.fr/annonces/appartement-paris-...   9571.428571
# 1311  https://www.pap.fr/annonces/appartement-paris-...   9814.814815
# 1312  https://www.pap.fr/annonces/appartement-paris-...  10340.909091
# 1313  https://www.pap.fr/annonces/appartement-paris-...   6292.307692
# 1314  https://www.pap.fr/annonces/appartement-paris-...   9555.555556
#
# [1315 rows x 8 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0  arrondissement    nb_pieces  nb_chambres      surface  \
# count  1315.000000     1315.000000  1315.000000   538.000000  1315.000000
# mean    235.743726      241.388593     2.704943     1.479554    59.538403
# std     149.241009     4137.411543     1.401108     1.118887    39.968355
# min       0.000000        1.000000     1.000000     0.000000     4.000000
# 25%     109.000000       10.000000     2.000000     1.000000    32.000000
# 50%     219.000000       14.000000     3.000000     1.000000    51.000000
# 75%     359.500000       17.000000     3.000000     2.000000    76.000000
# max     537.000000    75116.000000    10.000000     8.000000   486.000000
#
#                prix       prix_mc
# count  1.315000e+03   1315.000000
# mean   7.434337e+05  12365.133127
# std    7.231592e+05   2966.326759
# min    1.100000e+04   1982.954545
# 25%    3.810000e+05  10591.350601
# 50%    5.950000e+05  11991.250000
# 75%    8.970000e+05  13654.880066
# max    1.800000e+07  39900.000000

# %%
df.shape[0]
# Out:
# 1315

# %%
len(prix_mc)
# Out:
# 62

# %%
prix = df[['prix_mc','arrondissement']].groupby('arrondissement').mean().round().sort_values(by='prix_mc', ascending=False)
prix.reset_index(0, inplace=True)
prix
# Out:
#     arrondissement  prix_mc
# 0                1  17845.0
# 1                6  17712.0
# 2                7  16954.0
# 3                4  15984.0
# 4                8  15511.0
# 5                5  14477.0
# 6            75116  14303.0
# 7                2  14279.0
# 8                3  13734.0
# 9                9  13127.0
# 10              16  12711.0
# 11              17  12232.0
# 12              15  12050.0
# 13              14  11790.0
# 14              11  11727.0
# 15              10  11712.0
# 16              12  11313.0
# 17              18  11257.0
# 18              20  10534.0
# 19              13  10473.0
# 20              19   9619.0

# %%
paris = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
paris.choropleth(geo, key_on = "feature.properties.c_ar",
                 data = df, columns = ["arrondissement", "prix_mc"],
                 fill_color = "Spectral")
paris
# Out:
# C:\Users\Naomi\anaconda3.2020\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
