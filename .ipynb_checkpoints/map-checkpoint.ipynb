# %%
import folium
paris = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)

# %%
#paris

# %%
#folium.Marker([48.856578, 2.351828], popup = "PARIS").add_to(paris)
#paris

# %%
#folium.CircleMarker([48.856578, 2.351828], popup = "PARIS", radius = 10).add_to(paris)
#paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
geo = json.load(open("arrondissements.geojson"))

# %%
geo.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo["features"][0]['properties']
# Out:
# {'n_sq_co': 750001537,
#  'perimetre': 6483.68678565,
#  'l_ar': '6ème Ardt',
#  'surface': 2153095.58639283,
#  'geom_x_y': [48.8491303586, 2.33289799905],
#  'n_sq_ar': 750000006,
#  'l_aroff': 'Luxembourg',
#  'c_arinsee': 75106,
#  'c_ar': 6}

# %%
paris_arr_marker = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
for arr in geo["features"]:
    prop = arr["properties"]
    folium.Marker(prop["geom_x_y"], popup = prop["l_ar"]).add_to(paris_arr_marker)
paris_arr_marker
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
paris_arr_circle = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
for arr in geo["features"]:
    prop = arr["properties"]
    folium.CircleMarker(prop["geom_x_y"], 
                        popup = prop["l_ar"],
                        radius = prop["surface"] / 1000000).add_to(paris_arr_circle)
paris_arr_circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
paris = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
paris.choropleth( geo)
paris
# Out:
# C:\Users\Naomi\anaconda3.2020\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
df = pd.read_csv('pap.csv')

# %%
df
# Out:
#      arrondissement  nb_pieces  nb_chambres  surface     prix  \
# 0                 1          1            0       20   310000
# 1                 1          1            0       31   425000
# 2                 1          2            1       57   890000
# 3                 1          3            2       71  1100000
# 4                 1          2            1       50   745000
# ..              ...        ...          ...      ...      ...
# 533              18          1            0       28   268000
# 534              18          2            1       27   265000
# 535              18          2            1       44   455000
# 536              18          3            2       65   409000
# 537              18          2            1       45   430000
#
#                                                   lien       prix_mc
# 0    https://www.pap.fr/annonces/appartement-paris-...  15500.000000
# 1    https://www.pap.fr/annonces/appartement-paris-...  13709.677419
# 2    https://www.pap.fr/annonces/appartement-paris-...  15614.035088
# 3    https://www.pap.fr/annonces/appartement-paris-...  15492.957746
# 4    https://www.pap.fr/annonces/appartement-paris-...  14900.000000
# ..                                                 ...           ...
# 533  https://www.pap.fr/annonces/appartement-paris-...   9571.428571
# 534  https://www.pap.fr/annonces/appartement-paris-...   9814.814815
# 535  https://www.pap.fr/annonces/appartement-paris-...  10340.909091
# 536  https://www.pap.fr/annonces/appartement-paris-...   6292.307692
# 537  https://www.pap.fr/annonces/appartement-paris-...   9555.555556
#
# [538 rows x 7 columns]

# %%
df.describe()
# Out:
#        arrondissement   nb_pieces  nb_chambres     surface          prix  \
# count      538.000000  538.000000   538.000000  538.000000  5.380000e+02
# mean        12.241636    2.657993     1.479554   58.635688  7.497958e+05
# std          4.775907    1.452584     1.118887   40.271670  5.569425e+05
# min          1.000000    1.000000     0.000000    5.000000  4.000000e+04
# 25%          9.000000    2.000000     1.000000   30.000000  3.842500e+05
# 50%         13.000000    2.000000     1.000000   48.500000  5.990000e+05
# 75%         16.000000    3.000000     2.000000   76.750000  9.500000e+05
# max         18.000000   10.000000     8.000000  260.000000  4.300000e+06
#
#             prix_mc
# count    538.000000
# mean   12873.012493
# std     2535.743262
# min     6292.307692
# 25%    11254.960317
# 50%    12633.971292
# 75%    14087.301587
# max    23333.333333

# %%
arrondissement = []

for i in range(1,21):
    arrondissement.append(i)
    
for arr in arrondissement:
    prix_mc = []
    for index in range(df.shape[0]):
        if df.arrondissement[index] == arr:
            prix_mc.append(df.prix_mc[index])

# %%
df.shape[0]
# Out:
# 538

# %%
prix_mc
# Out:
# []

# %%
prix = df[['prix_mc','arrondissement']].groupby('arrondissement').mean().round().sort_values(by='prix_mc', ascending=False)
prix.reset_index(0, inplace=True)
prix
# Out:
#     arrondissement  prix_mc
# 0                7  16849.0
# 1                6  16433.0
# 2                1  15940.0
# 3                8  15791.0
# 4                4  15045.0
# 5                2  14631.0
# 6                3  13967.0
# 7                5  13925.0
# 8                9  13587.0
# 9               16  13119.0
# 10              15  12669.0
# 11              17  12617.0
# 12              11  11921.0
# 13              14  11732.0
# 14              12  11674.0
# 15              18  11394.0
# 16              13  10707.0
# 17              10  10637.0

# %%
paris = folium.Map(location = [48.856578, 2.351828], zoom_start = 12)
paris.choropleth(geo, key_on = "feature.properties.c_ar",
                 data = df, columns = ["arrondissement", "prix_mc"],
                 fill_color = "Spectral")
paris
# Out:
# C:\Users\Naomi\anaconda3.2020\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
